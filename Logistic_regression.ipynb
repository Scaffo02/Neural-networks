# %%
from scipy.io import loadmat
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import SGD

# %%
dataset = loadmat('dataset.mat')
data_set = loadmat('test_set.mat')

# %%
# Escludi le chiavi interne di MATLAB (__header__, ecc.)
chiavi_utili = [k for k in dataset.keys() if not k.startswith('__')]
chiavi_utili_t = [k for k in data_set.keys() if not k.startswith('__')]
# Supponendo che ci sia solo una variabile:
dati = dataset[chiavi_utili[0]].squeeze()
dati_t = data_set[chiavi_utili_t[0]].squeeze()
print(dati)
# Out:
# [[1.01761212 0.3645381  0.97395685 1.62703086 0.        ]
#  [0.78798706 0.78518016 0.78798706 0.43867355 1.        ]
#  [1.65485135 1.42285742 1.65485135 0.85429434 1.        ]
#  ...
#  [0.34867266 0.30048205 0.34867266 0.20597802 1.        ]
#  [0.6785579  0.72082457 0.97244512 0.93017846 0.        ]
#  [0.51636185 0.44349862 0.51636185 0.29775182 1.        ]]

# %%
#dividiamo i dati in training e test set in un rapport rispettivamente di 70% e 30% dei dati

# Training set
C_QS_traing = dati[0:245000,0]
C_RS_traing = dati[0:245000,1]
C_RT_traing = dati[0:245000,2]
C_QT_traing = dati[0:245000,3]
label_traing = dati[0:245000,4]

training_set = np.stack([C_QS_traing,C_RS_traing,C_RT_traing,C_QT_traing],axis=1)

#Validation set
C_QS_val = dati[245000:350000,0]
C_RS_val = dati[245000:350000,1]
C_RT_val = dati[245000:350000,2]
C_QT_val = dati[245000:350000,3]
label_val = dati[245000:350000,4]
val_set = np.stack([C_QS_val,C_RS_val,C_RT_val,C_QT_val],axis=1)

# Test set
C_QS_test = dati_t[0:dati_t.shape[0],0]
C_RS_test = dati_t[0:dati_t.shape[0],1]
C_RT_test = dati_t[0:dati_t.shape[0],2]
C_QT_test = dati_t[0:dati_t.shape[0],3]
label_test = dati_t[0:dati_t.shape[0],4]
test_set = np.stack([C_QS_test,C_RS_test,C_RT_test,C_QT_test],axis=1)

# %%
training_set
# Out:
# array([[1.01761212, 0.3645381 , 0.97395685, 1.62703086],
#        [0.78798706, 0.78518016, 0.78798706, 0.43867355],
#        [1.65485135, 1.42285742, 1.65485135, 0.85429434],
#        ...,
#        [0.37380086, 0.32193961, 0.37380086, 0.21994747],
#        [0.08574591, 0.11133193, 0.08574591, 0.02303689],
#        [0.13188384, 0.14867756, 0.13188384, 0.04290416]])

# %%
val_set
# Out:
# array([[1.64591652, 1.41498   , 1.64591652, 0.85033337],
#        [0.74213668, 0.63579211, 0.74213668, 0.41663417],
#        [0.09262019, 0.06357676, 0.07431436, 0.09091468],
#        ...,
#        [0.34867266, 0.30048205, 0.34867266, 0.20597802],
#        [0.6785579 , 0.72082457, 0.97244512, 0.93017846],
#        [0.51636185, 0.44349862, 0.51636185, 0.29775182]])

# %%
test_set
# Out:
# array([[1.40605406e-01, 1.13778262e-01, 1.40605406e-01, 8.66073927e-02],
#        [2.36305801e-01, 1.89890290e-01, 2.36305801e-01, 1.42419679e-01],
#        [2.42783180e-01, 1.95019396e-01, 2.42783180e-01, 1.46136355e-01],
#        ...,
#        [1.53753858e+00, 1.21360586e+00, 1.53753858e+00, 8.01730645e-01],
#        [3.95533488e-01, 3.32830936e-01, 3.72870422e-01, 5.32071422e-01],
#        [6.15201768e-04, 7.38925760e-04, 6.15201768e-04, 2.44760949e-04]])

# %%
print('Dimensioni del training set:',C_QS_traing.shape)
print('Dimensioni del validation set:',C_QS_val.shape)
print('Dimensioni del test set:',C_QS_test.shape)
# Out:
# Dimensioni del training set: (245000,)
# Dimensioni del validation set: (105000,)
# Dimensioni del test set: (175000,)

# %%
#Creiamo la nostra rete
input_dim = 4
# 4 features: C_QS, C_RS, C_RT, C_QT
model = keras.models.Sequential([
    keras.layers.Dense(1, input_dim=input_dim, activation='sigmoid')  # n_features = numero di feature nel dataset
])
# Out:
# c:\Users\aless\miniconda3\envs\neural_network\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5 (20.00 B)
#  Trainable params: 5 (20.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = SGD(learning_rate=0.08)
model.compile(loss="binary_crossentropy",
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
history = model.fit(training_set, label_traing, epochs=50,batch_size=5000, validation_data=(val_set, label_val))
# Out:
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3364 - loss: 1.1363 - val_accuracy: 0.5201 - val_loss: 0.7000
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5176 - loss: 0.6776 - val_accuracy: 0.5201 - val_loss: 0.6263
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6361 - loss: 0.6161 - val_accuracy: 0.8037 - val_loss: 0.5866
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7952 - loss: 0.5803 - val_accuracy: 0.7717 - val_loss: 0.5617
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7677 - loss: 0.5575 - val_accuracy: 0.7561 - val_loss: 0.5453
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7527 - loss: 0.5435 - val_accuracy: 0.7483 - val_loss: 0.5339
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7473 - loss: 0.5326 - val_accuracy: 0.7440 - val_loss: 0.5257
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7431 - loss: 0.5258 - val_accuracy: 0.7410 - val_loss: 0.5195
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7403 - loss: 0.5198 - val_accuracy: 0.7395 - val_loss: 0.5146
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7392 - loss: 0.5153 - val_accuracy: 0.7387 - val_loss: 0.5106
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7381 - loss: 0.5109 - val_accuracy: 0.7378 - val_loss: 0.5072
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7369 - loss: 0.5087 - val_accuracy: 0.7377 - val_loss: 0.5042
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7390 - loss: 0.5044 - val_accuracy: 0.7379 - val_loss: 0.5016
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7385 - loss: 0.5026 - val_accuracy: 0.7382 - val_loss: 0.4992
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7388 - loss: 0.4996 - val_accuracy: 0.7387 - val_loss: 0.4970
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7397 - loss: 0.4976 - val_accuracy: 0.7390 - val_loss: 0.4949
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7392 - loss: 0.4964 - val_accuracy: 0.7396 - val_loss: 0.4929
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7403 - loss: 0.4940 - val_accuracy: 0.7402 - val_loss: 0.4911
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7418 - loss: 0.4913 - val_accuracy: 0.7407 - val_loss: 0.4893
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7427 - loss: 0.4895 - val_accuracy: 0.7417 - val_loss: 0.4876
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7428 - loss: 0.4878 - val_accuracy: 0.7421 - val_loss: 0.4859
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7411 - loss: 0.4884 - val_accuracy: 0.7429 - val_loss: 0.4843
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7454 - loss: 0.4828 - val_accuracy: 0.7437 - val_loss: 0.4828
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7454 - loss: 0.4825 - val_accuracy: 0.7444 - val_loss: 0.4813
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7466 - loss: 0.4815 - val_accuracy: 0.7452 - val_loss: 0.4798
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7459 - loss: 0.4808 - val_accuracy: 0.7458 - val_loss: 0.4784
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7466 - loss: 0.4801 - val_accuracy: 0.7466 - val_loss: 0.4770
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7483 - loss: 0.4779 - val_accuracy: 0.7478 - val_loss: 0.4757
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7483 - loss: 0.4769 - val_accuracy: 0.7486 - val_loss: 0.4744
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7490 - loss: 0.4753 - val_accuracy: 0.7492 - val_loss: 0.4731
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7521 - loss: 0.4726 - val_accuracy: 0.7502 - val_loss: 0.4719
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7532 - loss: 0.4703 - val_accuracy: 0.7508 - val_loss: 0.4706
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7523 - loss: 0.4703 - val_accuracy: 0.7514 - val_loss: 0.4695
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7525 - loss: 0.4698 - val_accuracy: 0.7521 - val_loss: 0.4683
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7543 - loss: 0.4675 - val_accuracy: 0.7528 - val_loss: 0.4672
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7543 - loss: 0.4671 - val_accuracy: 0.7537 - val_loss: 0.4660
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7543 - loss: 0.4663 - val_accuracy: 0.7542 - val_loss: 0.4650
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7548 - loss: 0.4664 - val_accuracy: 0.7551 - val_loss: 0.4639
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7557 - loss: 0.4650 - val_accuracy: 0.7557 - val_loss: 0.4628
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7577 - loss: 0.4629 - val_accuracy: 0.7564 - val_loss: 0.4618
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7571 - loss: 0.4624 - val_accuracy: 0.7571 - val_loss: 0.4608
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7575 - loss: 0.4619 - val_accuracy: 0.7575 - val_loss: 0.4598
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7581 - loss: 0.4610 - val_accuracy: 0.7581 - val_loss: 0.4588
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7597 - loss: 0.4591 - val_accuracy: 0.7585 - val_loss: 0.4579
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7605 - loss: 0.4576 - val_accuracy: 0.7592 - val_loss: 0.4570
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7597 - loss: 0.4576 - val_accuracy: 0.7596 - val_loss: 0.4560
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7592 - loss: 0.4583 - val_accuracy: 0.7604 - val_loss: 0.4551
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7617 - loss: 0.4558 - val_accuracy: 0.7609 - val_loss: 0.4543
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7633 - loss: 0.4534 - val_accuracy: 0.7615 - val_loss: 0.4534
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7630 - loss: 0.4528 - val_accuracy: 0.7620 - val_loss: 0.4525

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
#Valutiamo il modello
model.evaluate(test_set,label_test)
# Out:
# 5469/5469 ━━━━━━━━━━━━━━━━━━━━ 16s 3ms/step - accuracy: 0.7632 - loss: 0.4522
# [0.45295974612236023, 0.7620056867599487]

# %%
predizioni = model.predict(test_set)
# Out:
# 5469/5469 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step

# %%
predizioni
# Out:
# array([[0.24603121],
#        [0.313309  ],
#        [0.3182433 ],
#        ...,
#        [0.9823803 ],
#        [0.26481766],
#        [0.16818069]], dtype=float32)

# %%
threshold = 0.5
pred = (predizioni> threshold).astype(int)
pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [0]])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(label_test, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)

plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
f1 = f1_score(label_test, pred)
precision = precision_score(label_test, pred) 
recall = recall_score(label_test, pred)
print('Precision:',precision)
print('Recall:',recall)
print('f1 score:',f1)
# Out:
# Precision: 0.7987957669383287
# Recall: 0.7234101148969453
# f1 score: 0.7592362431859041

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(label_test, predizioni)



plt.figure(figsize=(8, 6))
plt.plot(thresholds, precision[:-1], label='Precisione', color='blue')
plt.plot(thresholds, recall[:-1], label='Recall', color='green')
plt.xlabel('Threshold')
plt.ylabel('Valore')
plt.title('Precisione e Recall in funzione della Threshold')
plt.legend()
plt.grid(True)
plt.show()

# %%
#QUESTA PARTE è DA RIVEDERE
from sklearn.metrics import roc_curve,auc
import matplotlib.pyplot as plt

fpr,tpr,threshold = roc_curve(label_test, predizioni)
plt.plot([0,1],[0,1],'--')
plt.plot(fpr,tpr)
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')

# %%
roc_auc = auc(fpr, tpr)
print('AUC:',roc_auc)
# Out:
# AUC: 0.8859130403340687
